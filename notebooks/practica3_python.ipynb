# %%
import sys
import platform
import numpy as np
import pandas as pd

print("Python      :", sys.version)
print("Implementación:", platform.python_implementation())
print("NumPy       :", np.__version__)
print("pandas      :", pd.__version__)

assert sys.version_info[:2] == (3, 12), "Esta práctica requiere Python 3.12"
print("\nEntorno verificado correctamente.")
# Out:
# Python      : 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]
# Implementación: CPython
# NumPy       : 2.5.3
# pandas      : 3.0.6
#
# Entorno verificado correctamente.

# %% [markdown]
# ### Ejercicio 1 — Catálogo de productos como lista
#
# Una tienda gestiona su catálogo en una lista plana que alterna nombre de producto y precio. Trabaja con esta estructura sin convertirla todavía a diccionario.
#
# ```python
# catalogo = [
#     "Auriculares BT", 59.90,
#     "Smartwatch S2", 149.00,
#     "Tablet 10", 219.00,
#     "Cargador USB-C", 18.50,
#     "Cafetera Expres", 189.00,
#     "Robot Aspirador", 279.00,
# ]
# ```
#
# **Se pide:**
#
# 1. Imprime el número total de elementos de la lista y deduce cuántos productos hay.
# 2. Usando *slicing con paso*, crea `nombres` con todos los nombres y `precios` con todos los precios.
# 3. Obtén el precio del `"Robot Aspirador"` **sin escribir el índice a mano**: localiza su posición con `.index()` y usa esa posición para llegar al precio.
# 4. Crea `ultimos_tres_nombres` con los tres últimos productos usando índices negativos.
# 5. Calcula e imprime el precio medio del catálogo redondeado a dos decimales, usando únicamente `sum()`, `len()` y `round()`.
#
# **Comprobación:** `nombres` debe tener 6 elementos y `precios` debe sumar 914,40.
#
# > **Pista:** `lista[inicio:fin:paso]`. Con paso 2 desde el índice 0 obtienes las posiciones pares, desde el índice 1 las impares.
# >

# %%
catalogo = [
    "Auriculares BT", 59.90,
    "Smartwatch S2", 149.00,
    "Tablet 10", 219.00,
    "Cargador USB-C", 18.50,
    "Cafetera Expres", 189.00,
    "Robot Aspirador", 279.00,
]

totalElementos = len(catalogo)
numProductos = totalElementos
print(f"Total de elementos en la lista: {totalElementos}")
print(f"Total de productos: {numProductos}\n")

nombres = catalogo[0::2] 
precios = catalogo[1::2]  

idxRobot = catalogo.index("Robot Aspirador")
precioRobot = catalogo[idxRobot + 1] 
print(f"Precio del Robot Aspirador: {precioRobot}€\n")

ultimosTresNombres = nombres[-3:]
print(f"Últimos tres productos: {ultimosTresNombres}\n")

precioMedio = round(sum(precios) / len(precios), 2)
print(f"Precio medio del catálogo: {precioMedio}€\n")

print("Comprobación:")
print(f"Elementos en nombres (debe ser 6): {len(nombres)}")
print(f"Suma de precios (debe ser 914.4): {sum(precios)}")
# Out:
# Total de elementos en la lista: 12
# Total de productos: 12
#
# Precio del Robot Aspirador: 279.0€
#
# Últimos tres productos: ['Cargador USB-C', 'Cafetera Expres', 'Robot Aspirador']
#
# Precio medio del catálogo: 152.4€
#
# Comprobación:
# Elementos en nombres (debe ser 6): 6
# Suma de precios (debe ser 914.4): 914.4

# %% [markdown]
# ### Ejercicio 2 — Inventario multialmacén con listas anidadas
#
# El inventario de tres almacenes se representa como una lista de listas. Cada sublista sigue el formato `[codigo_almacen, producto, unidades, coste_unitario]`.
#
# ```python
# inventario = [
#     ["ALM-NORTE", "Robot Aspirador", 34, 201.50],
#     ["ALM-NORTE", "Monitor 27", 58, 142.00],
#     ["ALM-SUR",   "Silla Ergonomica", 12, 178.90],
#     ["ALM-SUR",   "Robot Aspirador", 7, 201.50],
#     ["ALM-ESTE",  "Cafetera Expres", 41, 131.20],
#     ["ALM-ESTE",  "Monitor 27", 25, 142.00],
# ]
# ```
#
# **Se pide:**
#
# 1. Imprime el nombre del producto de la **cuarta** fila usando doble indexación.
# 2. Crea una nueva lista `valor_stock` donde cada elemento sea `[producto, unidades * coste_unitario]` redondeado a dos decimales. Resuélvelo con un bucle `for` sobre `inventario`.
# 3. Calcula el **valor inmovilizado total** del inventario.
# 4. Extrae, mediante *slicing*, una sublista con solo las filas del `ALM-SUR` (usa el hecho de que están contiguas) y calcula su valor.
# 5. Explica en una celda Markdown de **dos frases** qué problema aparece si dos almacenes dejan de estar contiguos y por qué el *slicing* no es una estrategia robusta de filtrado.
#
# **Comprobación:** el valor inmovilizado total debe ser 27 573,50 € y el del `ALM-SUR`, 3 557,30 €.

# %%
inventario = [
    ["ALM-NORTE", "Robot Aspirador", 34, 201.50],
    ["ALM-NORTE", "Monitor 27", 58, 142.00],
    ["ALM-SUR",   "Silla Ergonomica", 12, 178.90],
    ["ALM-SUR",   "Robot Aspirador", 7, 201.50],
    ["ALM-ESTE",  "Cafetera Expres", 41, 131.20],
    ["ALM-ESTE",  "Monitor 27", 25, 142.00],
]

productoCuartaFila = inventario[3][1]
print(f"Producto de la 4ª fila: {productoCuartaFila}")

valorStock = []
for fila in inventario:
    producto = fila[1]
    unidades = fila[2]
    costeUnitario = fila[3]
    valor = round(unidades * costeUnitario, 2)
    valorStock.append([producto, valor])

valorTotal = sum(fila[1] for fila in valorStock)
print(f"Valor inmovilizado total: {valorTotal} €")

inventarioSur = inventario[2:4]
valorSur = round(sum(fila[2] * fila[3] for fila in inventarioSur), 2)
print(f"Valor del ALM-SUR: {valorSur} €")

print("\n Comprobacion")
print(f"¿El valor total es 27573.5?: {valorTotal == 27573.5}")
print(f"¿El valor SUR es 3557.3?: {valorSur == 3557.3}")
# Out:
# Producto de la 4ª fila: Robot Aspirador
# Valor inmovilizado total: 27573.5 €
# Valor del ALM-SUR: 3557.3 €
#
#  Comprobacion
# ¿El valor total es 27573.5?: True
# ¿El valor SUR es 3557.3?: True

# %% [markdown]
# **Explicacion:**
# El uso de slicing asume obligatoriamente que los registros están ordenados y agrupados en bloques contiguos predecibles. Si el inventario se desordena o se añaden nuevos registros intercalados, el *slicing* basado en posiciones capturará datos mezclados y erróneos, por lo que usar condiciones lógicas de filtrado (ej: `if fila[0] == "ALM-SUR"`) es la única estrategia realmente robusta.

# %% [markdown]
# ### Ejercicio 3 — Manipulación destructiva y copias de listas
#
# Este ejercicio trabaja el comportamiento interno de las listas (referencias frente a copias).
#
# ```python
# precios_originales = [59.90, 149.00, 219.00, 18.50, 189.00, 279.00]
# ```
#
# **Se pide:**
#
# 1. Crea `precios_rebajados = precios_originales` y modifica el primer elemento de `precios_rebajados` a `49.90`. Imprime **las dos listas** y explica qué ha ocurrido.
# 2. Restaura el valor original. Ahora crea dos copias independientes: una con `list()` y otra con *slicing* completo `[:]`. Demuestra con `print()` que modificar la copia ya no afecta al original.
# 3. Sobre una copia, aplica una rebaja del 10 % a **todos** los elementos usando un bucle `for` con `range(len(...))`.
# 4. Añade dos productos nuevos con `.extend()` y un tercero en la **posición 2** con `.insert()`.
# 5. Elimina el elemento de la posición 4 con `del` y el último con `.pop()`, guardando el valor extraído en una variable `descartado`.
# 6. Comprueba con `id()` que `precios_originales` y cada copia apuntan a objetos distintos en memoria.
#
# > **Pista:** una asignación con `=` no copia la lista, copia la referencia. Es el error más caro de depurar en proyectos de datos reales.
# >

# %%
preciosOriginales = [59.90, 149.00, 219.00, 18.50, 189.00, 279.00]

preciosRebajados = preciosOriginales
preciosRebajados[0] = 49.90
print(preciosOriginales)
print(preciosRebajados)

preciosOriginales[0] = 59.90

copiaList = list(preciosOriginales)
copiaSlicing = preciosOriginales[:]

copiaList[0] = 10.00
print(preciosOriginales)
print(copiaList)

for i in range(len(copiaSlicing)):
    copiaSlicing[i] = round(copiaSlicing[i] * 0.90, 2)

copiaSlicing.extend([150.00, 320.00])
copiaSlicing.insert(2, 75.00)

del copiaSlicing[4]
descartado = copiaSlicing.pop()

print(id(preciosOriginales))
print(id(copiaList))
print(id(copiaSlicing))
print(id(preciosOriginales) != id(copiaList) and id(preciosOriginales) != id(copiaSlicing))
# Out:
# [49.9, 149.0, 219.0, 18.5, 189.0, 279.0]
# [49.9, 149.0, 219.0, 18.5, 189.0, 279.0]
# [59.9, 149.0, 219.0, 18.5, 189.0, 279.0]
# [10.0, 149.0, 219.0, 18.5, 189.0, 279.0]
# 2557704586304
# 2557708761216
# 2557708756288
# True

# %% [markdown]
# **Explicacion:**
# Al asignar `preciosRebajados = preciosOriginales` no se ha copiado la lista, sino que se ha copiado la referencia. Ambas variables apuntan exactamente al mismo objeto en la memoria, por lo que cualquier modificación realizada en una se refleja instantáneamente en la otra.

# %% [markdown]
# ### Ejercicio 4 — Cola de pedidos pendientes
#
# La cola de pedidos de un almacén se gestiona como lista ordenada por prioridad.
#
# ```python
# cola = ["PED-10021", "PED-10007", "PED-10044", "PED-10012", "PED-10033", "PED-10008"]
# ```
#
# **Se pide:**
#
# 1. Invierte la cola usando *slicing* con paso negativo (sin `.reverse()`) y guárdala en `cola_invertida`.
# 2. Ordena `cola` alfabéticamente con `sorted()` **sin modificar la original** y comprueba que la original sigue intacta.
# 3. Ordena ahora la lista **en sitio** con `.sort(reverse=True)`.
# 4. Atiende los dos primeros pedidos: extráelos con `.pop(0)` y guárdalos en `atendidos`.
# 5. Inserta un pedido urgente `"PED-99999"` al principio de la cola.
# 6. Imprime un informe final con el número de pedidos atendidos, los pendientes y el porcentaje de avance redondeado a un decimal.

# %%
cola = ["PED-10021", "PED-10007", "PED-10044", "PED-10012", "PED-10033", "PED-10008"]

colaInvertida = cola[::-1]

colaOrdenada = sorted(cola)
print(cola)
print(colaOrdenada)

cola.sort(reverse=True)

atendidos = []
atendidos.append(cola.pop(0))
atendidos.append(cola.pop(0))

cola.insert(0, "PED-99999")

totalPedidos = len(atendidos) + len(cola)
porcentajeAvance = round((len(atendidos) / totalPedidos) * 100, 1)

print(f"Pedidos atendidos: {len(atendidos)}")
print(f"Pedidos pendientes: {len(cola)}")
print(f"Porcentaje de avance: {porcentajeAvance}%")
# Out:
# ['PED-10021', 'PED-10007', 'PED-10044', 'PED-10012', 'PED-10033', 'PED-10008']
# ['PED-10007', 'PED-10008', 'PED-10012', 'PED-10021', 'PED-10033', 'PED-10044']
# Pedidos atendidos: 2
# Pedidos pendientes: 5
# Porcentaje de avance: 28.6%

# %% [markdown]
# ### Ejercicio 5 — Funciones propias para el cálculo de importes
#
# **Se pide:**
#
# 1. Define la función `calcular_importe(unidades, precio_unitario, descuento_pct=0)` que devuelva el importe neto redondeado a dos decimales. El parámetro `descuento_pct` debe tener valor por defecto.
# 2. Define `resumen_pedido(unidades, precio_unitario, descuento_pct=0)` que devuelva **una tupla de tres elementos**: `(importe_bruto, ahorro, importe_neto)`.
# 3. Llama a `resumen_pedido` usando **argumentos por palabra clave** y desempaqueta el resultado en tres variables.
# 4. Documenta ambas funciones con *docstring* y muestra la ayuda con `help(calcular_importe)`.
# 5. Usa `max()`, `min()`, `sorted()` y `len()` sobre la lista `importes` que obtengas al aplicar `calcular_importe` a estos cinco pedidos:
#
#     ```python
#     pedidos = [
#         (3, 59.90, 10),
#         (1, 279.00, 0),
#         (5, 18.50, 20),
#         (2, 149.00, 5),
#         (4, 89.90, 15),
#     ]
#     ```
#
#     **Comprobación:** `calcular_importe(3, 59.90, 10)` debe devolver `161.73`.

# %%
def calcular_importe(unidades, precio_unitario, descuento_pct=0):
    """
    Calcula el importe neto de un pedido aplicando el descuento indicado.
    Devuelve el valor final redondeado a dos decimales.
    """
    importeBruto = unidades * precio_unitario
    descuento = importeBruto * (descuento_pct / 100)
    return round(importeBruto - descuento, 2)

def resumen_pedido(unidades, precio_unitario, descuento_pct=0):
    """
    Calcula los totales de una línea de pedido.
    Devuelve una tupla con el importe bruto, el ahorro y el importe neto.
    """
    importeBruto = unidades * precio_unitario
    ahorro = importeBruto * (descuento_pct / 100)
    importeNeto = importeBruto - ahorro
    return (round(importeBruto, 2), round(ahorro, 2), round(importeNeto, 2))

importeBruto, ahorro, importeNeto = resumen_pedido(unidades=3, precio_unitario=59.90, descuento_pct=10)
print(f"Bruto: {importeBruto} | Ahorro: {ahorro} | Neto: {importeNeto}\n")

help(calcular_importe)

pedidos = [
    (3, 59.90, 10),
    (1, 279.00, 0),
    (5, 18.50, 20),
    (2, 149.00, 5),
    (4, 89.90, 15),
]

listaImportes = []
for p in pedidos:
    listaImportes.append(calcular_importe(p[0], p[1], p[2]))

print(f"\nImporte máximo: {max(listaImportes)}")
print(f"Importe mínimo: {min(listaImportes)}")
print(f"Importes ordenados: {sorted(listaImportes)}")
print(f"Total de importes calculados: {len(listaImportes)}")

print(f"\nComprobación: {calcular_importe(3, 59.90, 10)}")
# Out:
# Bruto: 179.7 | Ahorro: 17.97 | Neto: 161.73
#
# Help on function calcular_importe in module __main__:
#
# calcular_importe(unidades, precio_unitario, descuento_pct=0)
#     Calcula el importe neto de un pedido aplicando el descuento indicado.
#     Devuelve el valor final redondeado a dos decimales.
#
#
# Importe máximo: 305.66
# Importe mínimo: 74.0
# Importes ordenados: [74.0, 161.73, 279.0, 283.1, 305.66]
# Total de importes calculados: 5
#
# Comprobación: 161.73

# %% [markdown]
# ### Ejercicio 6 — Normalización de códigos SKU con métodos
#
# El equipo de logística recibe códigos de producto en formatos inconsistentes.
#
# ```python
# skus_crudos = [
#     "  elc-0012-es ", "HOG-0045-ES", "dep-0003-pt  ",
#     "ofi-0021-es", "  ELC-0012-ES", "hog-0099-fr ",
# ]
# ```
#
# **Se pide:**
#
# 1. Crea `skus_limpios` aplicando a cada código: eliminación de espacios sobrantes (`.strip()`) y conversión a mayúsculas (`.upper()`).
# 2. Cuenta cuántas veces aparece `"ELC-0012-ES"` en la lista limpia con `.count()`.
# 3. Obtén la posición de la primera aparición de `"OFI-0021-ES"` con `.index()`.
# 4. Para cada SKU limpio, usa `.split("-")` para separar familia, número y país. Construye una lista de listas con esas tres partes.
# 5. Crea `skus_es` con solo los SKU cuyo país sea `"ES"` y sustituye en todos ellos el guion por un punto con `.replace()`.
# 6. Genera una cadena única separada por `" | "` usando `.join()` y muéstrala.
#
# > **Pista:** `.strip()`, `.upper()` y `.replace()` **devuelven** una nueva cadena; no modifican la original. `.append()` y `.sort()` sobre listas, en cambio, actúan en sitio y devuelven `None`.
# >
#
# ---

# %%
skus_crudos = [
    "  elc-0012-es ", "HOG-0045-ES", "dep-0003-pt  ",
    "ofi-0021-es", "  ELC-0012-ES", "hog-0099-fr ",
]

skus_limpios = []
for sku in skus_crudos:
    skus_limpios.append(sku.strip().upper())

print(skus_limpios.count("ELC-0012-ES"))

print(skus_limpios.index("OFI-0021-ES"))

skusSeparados = []
for sku in skus_limpios:
    skusSeparados.append(sku.split("-"))

skus_es = []
for sku in skus_limpios:
    if sku.split("-")[2] == "ES":
        skus_es.append(sku.replace("-", "."))

cadenaUnica = " | ".join(skus_es)
print(cadenaUnica)
# Out:
# 2
# 3
# ELC.0012.ES | HOG.0045.ES | OFI.0021.ES | ELC.0012.ES

# %% [markdown]
# ### Ejercicio 7 — Paquetes, importaciones y módulo propio
#
# **Se pide:**
#
# 1. Importa el paquete completo con `import math` y calcula la raíz cuadrada de `2809` con `math.sqrt()`.
# 2. Importa **selectivamente** `pi` y `ceil` con `from math import pi, ceil`. Calcula cuántos palés completos de 24 unidades hacen falta para enviar 1 375 unidades.
# 3. Importa `numpy` con alias `np` y `pandas` con alias `pd`, e imprime la versión de ambos con `np.__version__` y `pd.__version__`.
# 4. Usa el módulo `random` con semilla fija para generar 10 valoraciones de cliente entre 1 y 5:
#
#     ```python
#     import random
#
#     random.seed(42)
#     valoraciones = [random.randint(1, 5) for _ in range(10)]
#     print(valoraciones)
#     ```
#
# 5. Explica en **una frase** por qué fijar la semilla hace que el resultado sea el mismo para ti y para el profesor.
# 6. Crea el fichero `src/utilidades.py` copiando este contenido tal cual:
#
#     ```python
#     # src/utilidades.py
#     """Funciones auxiliares de la Práctica 3."""
#
#     def calcular_importe(unidades, precio_unitario, descuento_pct=0):
#         """Devuelve el importe neto de una línea de pedido."""
#         bruto = unidades * precio_unitario
#         return round(bruto * (1 - descuento_pct / 100), 2)
#
#     def clasificar_ticket(importe):
#         """Clasifica un importe en 'Bajo', 'Medio' o 'Alto'."""
#         if importe < 100:
#             return "Bajo"
#         elif importe < 400:
#             return "Medio"
#         return "Alto"
#     ```
#
# 7. Impórtalo desde el notebook y comprueba que funciona:
#
#     ```python
#     import sys
#     sys.path.append("../src")
#
#     from utilidades import calcular_importe, clasificar_ticket
#
#     print(calcular_importe(4, 89.90, 15))
#     print(clasificar_ticket(305.66))
#     ```
#
#
# **Comprobación:** `calcular_importe(4, 89.90, 15)` debe devolver `305.66` y `clasificar_ticket(305.66)` debe devolver `"Medio"`.
#
# > **Pista:** `sys.path.append("../src")` le indica a Python dónde buscar tu módulo, porque el notebook vive en `notebooks/` y el módulo en `src/`.
# >

# %%
import math

raiz = math.sqrt(2809)
print(raiz)

from math import pi, ceil

palesNecesarios = ceil(1375 / 24)
print(palesNecesarios)

import numpy as np
import pandas as pd

print(np.__version__)
print(pd.__version__)

import random

random.seed(42)
valoraciones = [random.randint(1, 5) for _ in range(10)]
print(valoraciones)
# Out:
# 53.0
# 58
# 2.5.3
# 3.0.6
# [1, 1, 3, 2, 2, 2, 1, 5, 1, 5]

# %% [markdown]
# **Explicacion:** Fijar la semilla inicializa el algoritmo subyacente del generador de números pseudoaleatorios en el mismo estado de partida exacto, lo que garantiza que la secuencia generada sea matemáticamente idéntica sin importar quién o dónde ejecute el código.

# %%
import sys
sys.path.append("../src")

from utilidades import calcular_importe, clasificar_ticket

print(calcular_importe(4, 89.90, 15))
print(clasificar_ticket(305.66))
# Out:
# 305.66
# Medio

# %% [markdown]
# ### Ejercicio 8 — Del cálculo con listas al cálculo vectorizado
#
# ```python
# unidades = [3, 1, 5, 2, 4, 6, 2, 8, 3, 1]
# precios  = [59.90, 279.00, 18.50, 149.00, 89.90, 27.50, 219.00, 14.90, 64.00, 239.00]
# ```
#
# **Se pide:**
#
# 1. Intenta calcular `unidades * precios` con las listas de Python y explica en una frase el resultado o el error obtenido.
# 2. Convierte ambas listas a arrays NumPy (`np_unidades`, `np_precios`) e imprime `dtype` y `shape` de cada uno.
# 3. Calcula el array `importes = np_unidades * np_precios` y su suma total.
# 4. Aplica un recargo logístico del 4 % a todos los importes con una única operación vectorizada.
# 5. Crea un array mixto a partir de `[1, "dos", 3.0, True]` y explica qué `dtype` resulta y por qué NumPy fuerza la homogeneidad de tipos.
# 6. Compara el tiempo de calcular los importes con un bucle `for` frente a la versión vectorizada usando `%timeit` en una celda mágica de JupyterLab.
#
# **Comprobación:** la suma de `importes` debe ser 2 362,00 € y hay 4 productos con precio unitario superior a 100 €.

# %%
import numpy as np

unidades = [3, 1, 5, 2, 4, 6, 2, 8, 3, 1]
precios = [59.90, 279.00, 18.50, 149.00, 89.90, 27.50, 219.00, 14.90, 64.00, 239.00]

np_unidades = np.array(unidades)
np_precios = np.array(precios)

print(np_unidades.dtype)
print(np_unidades.shape)
print(np_precios.dtype)
print(np_precios.shape)

importes = np_unidades * np_precios
sumaTotal = importes.sum()
print(sumaTotal)

importesConRecargo = importes * 1.04

arrayMixto = np.array([1, "dos", 3.0, True])
print(arrayMixto.dtype)
# Out:
# int64
# (10,)
# float64
# (10,)
# 2362.0
# <U32

# %% [markdown]
# **Explicacion:** Al intentar calcular `unidades * precios` con listas estándar de Python se produce un error `TypeError`. Esto ocurre porque el operador de multiplicación `*` entre dos listas no está soportado; en Python nativo, este operador solo sirve para repetir una lista por un número entero, no para multiplicar elemento a elemento. El `dtype` resultante de la matriz mixta es una cadena de texto (como `<U32`). NumPy fuerza la homogeneidad de tipos porque necesita almacenar los datos en bloques de memoria contiguos y predecibles para optimizar la velocidad en C. Al haber un string, promueve todos los demás elementos a texto, ya que es el único tipo capaz de representarlos a todos sin perder información.

# %%
# %timeit [unidades[i] * precios[i] for i in range(len(unidades))]

# %timeit np_unidades * np_precios
# Out:
# 921 ns ± 70.1 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# 1.1 μs ± 35 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Ejercicio 9 — Subsetting con máscaras booleanas
#
# Partiendo de los arrays `np_unidades`, `np_precios` e `importes` del ejercicio anterior:
#
# **Se pide:**
#
# 1. Crea la máscara booleana `caros = np_precios > 100` e imprímela. Observa que es un array de `True` y `False` con la misma longitud que `np_precios`.
# 2. Usa la máscara para extraer los precios que superan 100 €: `np_precios[caros]`.
# 3. Cuenta cuántos productos caros hay con `caros.sum()` y explica en una frase por qué sumar booleanos devuelve un número.
# 4. Aplica la **misma máscara** al array `importes` para obtener los importes de esas líneas. Calcula su suma.
# 5. Obtén las posiciones que cumplen la condición con `np.where(caros)`.
# 6. Crea una segunda máscara `varias = np_unidades >= 2` y combina ambas con `&`, recordando que cada condición va entre paréntesis:
#
#     ```python
#     seleccion = (np_precios > 100) & (np_unidades >= 2)
#     print(importes[seleccion])
#     ```
#
#
# **Comprobación:** hay 4 productos con precio unitario superior a 100 € y la suma de sus importes es 1 254,00 €.
#
# > **Pista:** con NumPy no se usan `and` ni `or`, sino `&` (y) y `|` (o). Sin los paréntesis el resultado es un error, porque `&` se evalúa antes que `>`.
# >

# %%
caros = np_precios > 100
print(caros)

preciosCaros = np_precios[caros]
print(preciosCaros)

cantidadCaros = caros.sum()
print(cantidadCaros)

importesCaros = importes[caros]
sumaImportesCaros = importesCaros.sum()
print(sumaImportesCaros)

posicionesCaros = np.where(caros)
print(posicionesCaros)

varias = np_unidades >= 2
seleccion = (np_precios > 100) & (np_unidades >= 2)
print(importes[seleccion])

print("\n Comprobaciones:")
print(f"Productos caros: {cantidadCaros}")
print(f"Suma importes caros: {sumaImportesCaros}")
# Out:
# [False  True False  True False False  True False False  True]
# [279. 149. 219. 239.]
# 4
# 1254.0
# (array([1, 3, 6, 9]),)
# [298. 438.]
#
#  Comprobaciones:
# Productos caros: 4
# Suma importes caros: 1254.0

# %% [markdown]
# **Explicacion:** Sumar booleanos devuelve un número porque internamente Python y NumPy tratan el valor `True` como un 1 y el valor `False` como un 0, haciendo que la suma actúe en la práctica como un contador de las condiciones que se cumplen.

# %% [markdown]
# ### Ejercicio 10 — Matriz de ventas por trimestre y región
#
# ```python
# import numpy as np
#
# # Filas: T1, T2, T3  |  Columnas: Norte, Sur, Este, Oeste, Centro
# ventas_2d = np.array([
#     [15200.50, 11800.25, 12950.00,  9870.40, 13400.10],
#     [16840.75, 12310.60, 13480.90, 11020.35, 14100.80],
#     [12535.72, 10663.06, 11221.59, 12673.08, 12334.38],
# ])
# ```
#
# **Se pide:**
#
# 1. Imprime `shape`, `ndim` y `size` del array y explica qué representa cada uno en este contexto de negocio.
# 2. Extrae la fila del segundo trimestre y la columna de la región Centro.
# 3. Obtén el valor de T3 en la región Este mediante indexación 2D.
# 4. Extrae con *slicing* la submatriz de T1 y T2 para las tres primeras regiones.
# 5. Calcula el total por trimestre (`axis=1`) y el total por región (`axis=0`).
# 6. Aplica una previsión de crecimiento del 6 % a T3 sumando el resultado como una **cuarta fila** con `np.vstack()`.
# 7. Identifica la región con mayor facturación acumulada usando `np.argmax()` sobre los totales por región, y traduce el índice a nombre con una lista de etiquetas.

# %%
import numpy as np

ventas_2d = np.array([
    [15200.50, 11800.25, 12950.00,  9870.40, 13400.10],
    [16840.75, 12310.60, 13480.90, 11020.35, 14100.80],
    [12535.72, 10663.06, 11221.59, 12673.08, 12334.38],
])

print(ventas_2d.shape)
print(ventas_2d.ndim)
print(ventas_2d.size)

filaT2 = ventas_2d[1, :]
colCentro = ventas_2d[:, 4]
print(filaT2)
print(colCentro)

valorT3Este = ventas_2d[2, 2]
print(valorT3Este)

submatriz = ventas_2d[0:2, 0:3]
print(submatriz)

totalTrimestre = ventas_2d.sum(axis=1)
totalRegion = ventas_2d.sum(axis=0)
print(totalTrimestre)
print(totalRegion)

t4Previsto = ventas_2d[2] * 1.06
ventasActualizadas = np.vstack((ventas_2d, t4Previsto))
print(ventasActualizadas)

etiquetasRegiones = ["Norte", "Sur", "Este", "Oeste", "Centro"]
indiceMax = np.argmax(totalRegion)
regionLider = etiquetasRegiones[indiceMax]
print(regionLider)
# Out:
# (3, 5)
# 2
# 15
# [16840.75 12310.6  13480.9  11020.35 14100.8 ]
# [13400.1  14100.8  12334.38]
# 11221.59
# [[15200.5  11800.25 12950.  ]
#  [16840.75 12310.6  13480.9 ]]
# [63221.25 67753.4  59427.83]
# [44576.97 34773.91 37652.49 33563.83 39835.28]
# [[15200.5    11800.25   12950.      9870.4    13400.1   ]
#  [16840.75   12310.6    13480.9    11020.35   14100.8   ]
#  [12535.72   10663.06   11221.59   12673.08   12334.38  ]
#  [13287.8632 11302.8436 11894.8854 13433.4648 13074.4428]]
# Norte

# %% [markdown]
# **Explicacion:** En este contexto de negocio, `shape` (3, 5) representa la estructura de la matriz indicando que hay 3 trimestres y 5 regiones; `ndim` (2) indica que los datos están en dos dimensiones formando una tabla bidimensional; y `size` (15) representa el número total de registros individuales de ventas que contiene la matriz.

# %% [markdown]
# ### Ejercicio 11 — Estadística descriptiva sobre telemetría simulada
#
# **Se pide:**
#
# 1. Genera con `rng = np.random.default_rng(2024)` dos arrays de 500 elementos: `temperatura` con `rng.normal(68, 6.5, 500)` y `vibracion` con `np.abs(rng.normal(2.4, 0.8, 500))`.
# 2. Calcula media, mediana, desviación típica, mínimo y máximo de `temperatura`. Compara media y mediana y razona en una frase qué indica la diferencia.
# 3. Calcula los percentiles 25, 50, 75 y 95 de `vibracion` con `np.percentile()`.
# 4. Apila ambos arrays en una matriz de forma `(500, 2)` con `np.column_stack()` y verifica el `shape`.
# 5. Calcula la matriz de correlación con `np.corrcoef()` y explica en una frase si existe relación lineal entre temperatura y vibración en estos datos simulados.
# 6. Define `umbral = media + 2 * desviación` de la temperatura, cuenta cuántas lecturas lo superan y calcula qué porcentaje del total representan.
# 7. Explica en dos frases por qué fijar la semilla (`default_rng(2024)`) es imprescindible para que un análisis sea reproducible por un tercero.

# %%
import numpy as np

rng = np.random.default_rng(2024)
temperatura = rng.normal(68, 6.5, 500)
vibracion = np.abs(rng.normal(2.4, 0.8, 500))

mediaTemp = np.mean(temperatura)
medianaTemp = np.median(temperatura)
desviacionTemp = np.std(temperatura)
minimoTemp = np.min(temperatura)
maximoTemp = np.max(temperatura)

print(mediaTemp)
print(medianaTemp)
print(desviacionTemp)
print(minimoTemp)
print(maximoTemp)

percentilesVibracion = np.percentile(vibracion, [25, 50, 75, 95])
print(percentilesVibracion)

matrizApilada = np.column_stack((temperatura, vibracion))
print(matrizApilada.shape)

matrizCorrelacion = np.corrcoef(temperatura, vibracion)
print(matrizCorrelacion)

umbral = mediaTemp + 2 * desviacionTemp
lecturasSuperadas = np.sum(temperatura > umbral)
porcentajeSuperadas = (lecturasSuperadas / len(temperatura)) * 100

print(lecturasSuperadas)
print(porcentajeSuperadas)
# Out:
# 68.03192414779825
# 68.13342844453155
# 6.501603731938141
# 49.014430627351686
# 88.2903599137993
# [1.89488326 2.39381414 2.92451892 3.72951895]
# (500, 2)
# [[1.         0.00673339]
#  [0.00673339 1.        ]]
# 11
# 2.1999999999999997

# %% [markdown]
# **Explicacion sobre media y mediana:** La similitud casi exacta entre la media y la mediana indica que la distribución de las temperaturas es simétrica (típicamente una campana de Gauss normal), sin que existan valores atípicos extremos que sesguen la media hacia un lado.
#
# **Explicacion sobre la correlación:** Al observar un valor muy cercano a 0 en las posiciones fuera de la diagonal principal de la matriz (aprox. -0.06), se concluye que no existe ninguna relación lineal entre la temperatura y la vibración en estos datos simulados.
#
# **Explicacion sobre la semilla:** Fijar la semilla obliga al algoritmo a iniciar siempre desde el mismo estado matemático exacto para generar los números pseudoaleatorios. Esto es imprescindible porque garantiza que un tercero obtendrá exactamente el mismo conjunto de datos y los mismos resultados al reproducir el código, asegurando la validez del análisis.

# %% [markdown]
# ### Ejercicio 12 — Diccionarios simples y anidados
#
# **Se pide:**
#
# 1. Crea el diccionario `tarifas_envio` con estos pares: `Norte: 4.95`, `Sur: 5.50`, `Este: 5.20`, `Oeste: 6.10`, `Centro: 3.90`.
# 2. Accede a la tarifa de `"Este"` e imprímela.
# 3. Añade la región `"Insular"` con tarifa `9.80` y actualiza `"Oeste"` a `5.95`.
# 4. Elimina `"Sur"` con `del` y comprueba con el operador `in` que ya no existe.
# 5. Recorre el diccionario con `.items()` e imprime una línea por región con formato `Norte -> 4.95 €`.
# 6. Construye el diccionario **anidado** `red_logistica` donde cada región sea una clave y su valor otro diccionario con las claves `almacen`, `tarifa` y `entrega_h`:
#
#     ```python
#     red_logistica = {
#         "Norte":  {"almacen": "ALM-NORTE", "tarifa": 4.95, "entrega_h": 24},
#         "Este":   {"almacen": "ALM-ESTE",  "tarifa": 5.20, "entrega_h": 48},
#         "Centro": {"almacen": "ALM-CENTRO","tarifa": 3.90, "entrega_h": 24},
#     }
#     ```
#
# 7. Accede al tiempo de entrega del almacén del Este mediante doble clave.
# 8. Añade la región `"Oeste"` completa al diccionario anidado y recorre toda la estructura con un bucle anidado para imprimir un informe legible.
# 9. Explica en dos frases cuándo conviene un diccionario frente a una lista, en términos de acceso y de significado de la clave.

# %%
tarifas_envio = {
    "Norte": 4.95,
    "Sur": 5.50,
    "Este": 5.20,
    "Oeste": 6.10,
    "Centro": 3.90
}

print(tarifas_envio["Este"])

tarifas_envio["Insular"] = 9.80
tarifas_envio["Oeste"] = 5.95

del tarifas_envio["Sur"]
print("Sur" in tarifas_envio)

for region, tarifa in tarifas_envio.items():
    print(f"{region} -> {tarifa} €")

red_logistica = {
    "Norte":  {"almacen": "ALM-NORTE", "tarifa": 4.95, "entrega_h": 24},
    "Este":   {"almacen": "ALM-ESTE",  "tarifa": 5.20, "entrega_h": 48},
    "Centro": {"almacen": "ALM-CENTRO","tarifa": 3.90, "entrega_h": 24},
}

print(red_logistica["Este"]["entrega_h"])

red_logistica["Oeste"] = {"almacen": "ALM-OESTE", "tarifa": 5.95, "entrega_h": 48}

for region, datos in red_logistica.items():
    print(f"Región: {region}")
    for clave, valor in datos.items():
        print(f"  {clave}: {valor}")
# Out:
# 5.2
# False
# Norte -> 4.95 €
# Este -> 5.2 €
# Oeste -> 5.95 €
# Centro -> 3.9 €
# Insular -> 9.8 €
# 48
# Región: Norte
#   almacen: ALM-NORTE
#   tarifa: 4.95
#   entrega_h: 24
# Región: Este
#   almacen: ALM-ESTE
#   tarifa: 5.2
#   entrega_h: 48
# Región: Centro
#   almacen: ALM-CENTRO
#   tarifa: 3.9
#   entrega_h: 24
# Región: Oeste
#   almacen: ALM-OESTE
#   tarifa: 5.95
#   entrega_h: 48

# %% [markdown]
# **Explicacion:** Un diccionario es mucho más conveniente que una lista cuando necesitamos acceder a los datos de forma instantánea a través de un identificador único (clave) en lugar de depender de una posición numérica estricta. Además, usar claves de texto aporta un significado semántico directo al valor que almacenan, haciendo que la estructura de datos se explique por sí misma.

# %% [markdown]
# ### Ejercicio 13 — De diccionario a DataFrame y lectura de CSV
#
# **Se pide:**
#
# 1. Construye este diccionario y conviértelo en un DataFrame llamado `almacenes` con `pd.DataFrame()`:
#
#     ```python
#     almacenes = {
#         "codigo":    ["ALM-NORTE", "ALM-SUR", "ALM-ESTE", "ALM-OESTE", "ALM-CENTRO"],
#         "ciudad":    ["Bilbao", "Sevilla", "Valencia", "Vigo", "Madrid"],
#         "m2":        [4200, 3100, 3800, 2600, 6500],
#         "operarios": [48, 31, 39, 22, 74],
#     }
#     ```
#
# 2. Imprime el DataFrame y observa el índice numérico que pandas ha creado automáticamente.
# 3. Convierte la columna `codigo` en índice con `.set_index("codigo")` y vuelve a imprimirlo.
# 4. Carga los tres ficheros CSV:
#
#     ```python
#     ventas = pd.read_csv("../data/ventas_retail.csv")
#     empleados = pd.read_csv("../data/empleados.csv", index_col="id_empleado")
#     sensores = pd.read_csv("../data/sensores_planta.csv")
#     ```
#
# 5. Para `ventas`, muestra `head(8)`, `tail(3)` y `shape`.
# 6. Ejecuta `ventas.info()` e identifica qué columnas son numéricas y cuáles de texto.
# 7. Cuenta los valores ausentes por columna con `ventas.isna().sum()` e indica en una frase en qué columnas se concentran.
# 8. Imprime el `shape` de los tres DataFrames.
#
# **Comprobación:** `ventas` debe tener 420 filas; `empleados`, 180; `sensores`, 600.

# %%
import pandas as pd

datosAlmacenes = {
    "codigo":    ["ALM-NORTE", "ALM-SUR", "ALM-ESTE", "ALM-OESTE", "ALM-CENTRO"],
    "ciudad":    ["Bilbao", "Sevilla", "Valencia", "Vigo", "Madrid"],
    "m2":        [4200, 3100, 3800, 2600, 6500],
    "operarios": [48, 31, 39, 22, 74],
}

almacenes = pd.DataFrame(datosAlmacenes)
print(almacenes)

almacenes = almacenes.set_index("codigo")
print(almacenes)

ventas = pd.read_csv("../data/ventas_retail.csv")
empleados = pd.read_csv("../data/empleados.csv", index_col="id_empleado")
sensores = pd.read_csv("../data/sensores_planta.csv")

print(ventas.head(8))
print(ventas.tail(3))
print(ventas.shape)

ventas.info()

nulosVentas = ventas.isna().sum()
print(nulosVentas)

print(ventas.shape)
print(empleados.shape)
print(sensores.shape)
# Out:
#        codigo    ciudad    m2  operarios
# 0   ALM-NORTE    Bilbao  4200         48
# 1     ALM-SUR   Sevilla  3100         31
# 2    ALM-ESTE  Valencia  3800         39
# 3   ALM-OESTE      Vigo  2600         22
# 4  ALM-CENTRO    Madrid  6500         74
#               ciudad    m2  operarios
# codigo
# ALM-NORTE     Bilbao  4200         48
# ALM-SUR      Sevilla  3100         31
# ALM-ESTE    Valencia  3800         39
# ALM-OESTE       Vigo  2600         22
# ALM-CENTRO    Madrid  6500         74
#    id_pedido       fecha  region    categoria          producto  unidades  \
# 0  PED-10153  2025-01-01  Centro  Electronica        Tablet 10"         2
# 1  PED-10030  2025-01-02     Sur      Deporte   Zapatilla Trail         4
# 2  PED-10343  2025-01-02   Oeste      Oficina  Teclado Mecanico         3
# 3  PED-10298  2025-01-02   Oeste        Hogar   Robot Aspirador         6
# 4  PED-10144  2025-01-03     Sur      Deporte       Mochila 30L         5
# 5  PED-10225  2025-01-03   Norte        Hogar   Robot Aspirador         6
# 6  PED-10137  2025-01-04    Este        Hogar   Cafetera Expres         2
# 7  PED-10193  2025-01-04  Centro      Deporte   Zapatilla Trail         5
#
#    precio_unitario  descuento_pct        canal  satisfaccion
# 0            219.0             20       Tienda           3.0
# 1            119.0              0       Online           5.0
# 2             89.9             10       Tienda           1.0
# 3            279.0             15       Tienda           2.0
# 4             64.0             20       Tienda           4.0
# 5            279.0              0  Marketplace           3.0
# 6            189.0              5       Online           1.0
# 7            119.0              0       Online           1.0
#      id_pedido       fecha  region categoria          producto  unidades  \
# 417  PED-10010  2025-09-29    Este   Oficina  Silla Ergonomica         8
# 418  PED-10197  2025-09-29    Este     Hogar       Lampara LED         7
# 419  PED-10119  2025-09-30  Centro   Oficina       Organizador         2
#
#      precio_unitario  descuento_pct        canal  satisfaccion
# 417            239.0              0  Marketplace           5.0
# 418             27.5             15  Marketplace           3.0
# 419             21.0             20       Online           2.0
# (420, 10)
# <class 'pandas.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_pedido        420 non-null    str
#  1   fecha            420 non-null    str
#  2   region           420 non-null    str
#  3   categoria        420 non-null    str
#  4   producto         420 non-null    str
#  5   unidades         420 non-null    int64
#  6   precio_unitario  420 non-null    float64
#  7   descuento_pct    420 non-null    int64
#  8   canal            415 non-null    str
#  9   satisfaccion     411 non-null    float64
# dtypes: float64(2), int64(2), str(6)
# memory usage: 32.9 KB
# id_pedido          0
# fecha              0
# region             0
# categoria          0
# producto           0
# unidades           0
# precio_unitario    0
# descuento_pct      0
# canal              5
# satisfaccion       9
# dtype: int64
# (420, 10)
# (180, 8)
# (600, 8)

# %% [markdown]
# **Explicacion:** Al revisar la información del DataFrame, se identifica que las columnas numéricas (`int64` o `float64`) son `unidades`, `precio_unitario`, `descuento_pct` y `satisfaccion`, mientras que las columnas de texto (`object`) son `id_pedido`, `fecha`, `region`, `categoria`, `producto` y `canal`. Los valores ausentes se concentran exclusivamente en las columnas `canal` y `satisfaccion`.

# %% [markdown]
# ### Ejercicio 14 — Selección con corchetes, `loc` e `iloc`
#
# Trabaja sobre el DataFrame `empleados` con `id_empleado` como índice.
#
# **Se pide:**
#
# 1. Selecciona la columna `salario_base` como **Serie** y como **DataFrame**. Muestra el `type()` de cada resultado.
# 2. Selecciona las columnas `departamento`, `ciudad` y `salario_base` a la vez.
# 3. Extrae las filas de la 10 a la 15 (ambas incluidas en la posición) usando corchetes con *slicing*.
# 4. Con `loc`, obtén la fila completa del empleado `EMP-1042`.
# 5. Con `loc`, obtén el `departamento` y la `modalidad` de los empleados `EMP-1005`, `EMP-1020` y `EMP-1099`.
# 6. Con `iloc`, obtén las tres primeras filas y las columnas en posición 2 y 5.
# 7. Con `loc`, selecciona **todas las filas** y solo las columnas `nombre` y `bonus_pct`.
# 8. Explica en una tabla Markdown de tres filas la diferencia entre corchetes, `loc` e `iloc`, indicando si trabajan por etiqueta o por posición.

# %%
salarioSerie = empleados["salario_base"]
salarioDf = empleados[["salario_base"]]
print(type(salarioSerie))
print(type(salarioDf))

columnasMultiples = empleados[["departamento", "ciudad", "salario_base"]]
print(columnasMultiples)

filasSlicing = empleados[10:16]
print(filasSlicing)

empleado1042 = empleados.loc["EMP-1042"]
print(empleado1042)

empleadosEspecificos = empleados.loc[["EMP-1005", "EMP-1020", "EMP-1099"], ["departamento", "modalidad"]]
print(empleadosEspecificos)

filasColumnasPosicion = empleados.iloc[:3, [2, 5]]
print(filasColumnasPosicion)

todasFilasColumnas = empleados.loc[:, ["nombre", "bonus_pct"]]
print(todasFilasColumnas)
# Out:
# <class 'pandas.Series'>
# <class 'pandas.DataFrame'>
#             departamento     ciudad  salario_base
# id_empleado
# EMP-1001      Ingenieria   Valencia         43297
# EMP-1002         Soporte   Valencia         32554
# EMP-1003     Operaciones   Valencia         47738
# EMP-1004          Ventas  Barcelona         39733
# EMP-1005        Finanzas     Madrid         44990
# ...                  ...        ...           ...
# EMP-1176          Ventas    Sevilla         37301
# EMP-1177          Ventas  Barcelona         44604
# EMP-1178        Finanzas     Bilbao         46786
# EMP-1179         Soporte     Madrid         35736
# EMP-1180      Ingenieria     Madrid         46315
#
# [180 rows x 3 columns]
#                      nombre departamento     ciudad  antiguedad_anios  \
# id_empleado
# EMP-1011       Ainhoa Rojas      Soporte  Barcelona                12
# EMP-1012      Jorge Aguilar   Ingenieria     Madrid                 7
# EMP-1013      Mateo Serrano       Ventas     Madrid                15
# EMP-1014         Noa Pastor    Marketing  Barcelona                13
# EMP-1015       Ivan Aguilar     Finanzas  Barcelona                10
# EMP-1016     Valeria Ferrer   Ingenieria     Malaga                17
#
#              salario_base  bonus_pct   modalidad  horas_formacion
# id_empleado
# EMP-1011            38857          3      Remoto             17.0
# EMP-1012            45762          7  Presencial             45.0
# EMP-1013            46312         12     Hibrido              6.0
# EMP-1014            45508         12      Remoto             26.0
# EMP-1015            50055          0      Remoto             18.0
# EMP-1016            61274          5  Presencial              8.0
# nombre              Julia Pastor
# departamento             Soporte
# ciudad                    Madrid
# antiguedad_anios               8
# salario_base               34121
# bonus_pct                      3
# modalidad             Presencial
# horas_formacion              5.0
# Name: EMP-1042, dtype: object
#             departamento   modalidad
# id_empleado
# EMP-1005        Finanzas      Remoto
# EMP-1020          Ventas      Remoto
# EMP-1099      Ingenieria  Presencial
#                ciudad  bonus_pct
# id_empleado
# EMP-1001     Valencia          3
# EMP-1002     Valencia          3
# EMP-1003     Valencia          0
#                      nombre  bonus_pct
# id_empleado
# EMP-1001       Elena Ibanez          3
# EMP-1002       Irene Merino          3
# EMP-1003       Victor Rojas          0
# EMP-1004         Noa Molina         10
# EMP-1005       Clara Ibanez          5
# ...                     ...        ...
# EMP-1176         Alba Nieto          7
# EMP-1177       Pablo Prieto          0
# EMP-1178        Hugo Merino          5
# EMP-1179        Raul Merino          5
# EMP-1180     Victor Aguilar          3
#
# [180 rows x 2 columns]

# %% [markdown]
# **Explicacion:**
#
# | Método | Tipo de acceso | Uso principal |
# | :--- | :--- | :--- |
# | **Corchetes `[]`** | Mixto | Seleccionar columnas por su nombre o recortar filas por posición (slicing). |
# | **`.loc[]`** | Por etiqueta | Seleccionar filas y columnas a través de los nombres o etiquetas explícitas de sus índices. |
# | **`.iloc[]`** | Por posición | Seleccionar filas y columnas usando posiciones numéricas enteras (de 0 a N-1). |

# %% [markdown]
# ### Ejercicio 15 — Columnas calculadas, agregación y exportación
#
# Trabaja sobre `ventas`.
#
# **Se pide:**
#
# 1. Crea la columna `importe_bruto = unidades * precio_unitario`.
# 2. Crea la columna `importe_neto` aplicando `descuento_pct`, redondeada a dos decimales.
# 3. Crea la columna `ticket_medio = importe_neto / unidades`.
# 4. Agrupa por `region` y calcula la suma de `importe_neto`, ordenada de mayor a menor.
# 5. Agrupa por `categoria` y `canal` a la vez, y calcula `importe_neto` medio y `unidades` totales usando `.agg()` con un diccionario de funciones.
# 6. Obtén el **top 5 de productos** por facturación neta con `.groupby()`, `.sum()` y `.nlargest()`.
# 7. Rellena los nulos de `satisfaccion` con la mediana de la columna y los de `canal` con el texto `"Desconocido"`.
# 8. Exporta el resultado agrupado por región a `../outputs/facturacion_por_region.csv`.
#
# **Comprobación:** la facturación neta total debe ser 190 402,48 € y la región líder, **Norte**.

# %%
ventas["importe_bruto"] = ventas["unidades"] * ventas["precio_unitario"]

ventas["importe_neto"] = round(ventas["importe_bruto"] * (1 - ventas["descuento_pct"] / 100), 2)

ventas["ticket_medio"] = ventas["importe_neto"] / ventas["unidades"]

facturacionPorRegion = ventas.groupby("region")["importe_neto"].sum().sort_values(ascending=False)
print("Facturación por Región ")
print(facturacionPorRegion)

aggCategoriaCanal = ventas.groupby(["categoria", "canal"]).agg({
    "importe_neto": "mean",
    "unidades": "sum"
})
print("\n Agrupación Categoría y Canal")
print(aggCategoriaCanal)

top5Productos = ventas.groupby("producto")["importe_neto"].sum().nlargest(5)
print("\n Top 5 Productos")
print(top5Productos)

medianaSatisfaccion = ventas["satisfaccion"].median()
ventas["satisfaccion"] = ventas["satisfaccion"].fillna(medianaSatisfaccion)
ventas["canal"] = ventas["canal"].fillna("Desconocido")

facturacionPorRegion.to_csv("../outputs/facturacion_por_region.csv")

totalNeto = ventas["importe_neto"].sum()
print(f"\nComprobación: Facturación neta total = {totalNeto} €")
# Out:
# Facturación por Región
# region
# Norte     44576.98
# Centro    39835.28
# Este      37652.49
# Sur       34773.90
# Oeste     33563.82
# Name: importe_neto, dtype: float64
#
#  Agrupación Categoría y Canal
#                          importe_neto  unidades
# categoria   canal
# Deporte     Desconocido     32.000000         1
#             Marketplace    311.646000       111
#             Online         292.234583       225
#             Tienda         189.056667       157
# Electronica Desconocido    139.732500        15
#             Marketplace    427.720435        95
#             Online         426.703208       242
#             Tienda         419.820417       199
# Hogar       Marketplace    665.550000        82
#             Online         447.141452       278
#             Tienda         889.918571       145
# Oficina     Marketplace    752.753750        83
#             Online         480.236977       179
#             Tienda         597.192143       124
#
#  Top 5 Productos
# producto
# Robot Aspirador     32322.15
# Tablet 10"          24068.10
# Silla Ergonomica    22394.30
# Smartwatch S2       20316.15
# Cafetera Expres     19778.85
# Name: importe_neto, dtype: float64
#
# Comprobación: Facturación neta total = 190402.47000000003 €
